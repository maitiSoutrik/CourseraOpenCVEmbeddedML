# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import PIL

# %%
img_path = 'content/cat_256X256.jpeg'
img = PIL.Image.open(img_path).convert('L')
print(img)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FA0A8656830>

# %%
img_arr = np.asarray(img)
print(img_arr.shape)
print(img_arr)
# Out:
# (256, 256)
# [[175 176 173 ... 131 130 128]
#  [176 177 175 ... 132 130 128]
#  [176 178 177 ... 131 129 126]
#  ...
#  [149 159 162 ...  91  91  93]
#  [171 172 174 ...  97  96  95]
#  [196 190 188 ...  99  97  95]]

# %%
# normalizing the img_arr
print(img_arr/255)
# Out:
# [[0.68627451 0.69019608 0.67843137 ... 0.51372549 0.50980392 0.50196078]
#  [0.69019608 0.69411765 0.68627451 ... 0.51764706 0.50980392 0.50196078]
#  [0.69019608 0.69803922 0.69411765 ... 0.51372549 0.50588235 0.49411765]
#  ...
#  [0.58431373 0.62352941 0.63529412 ... 0.35686275 0.35686275 0.36470588]
#  [0.67058824 0.6745098  0.68235294 ... 0.38039216 0.37647059 0.37254902]
#  [0.76862745 0.74509804 0.7372549  ... 0.38823529 0.38039216 0.37254902]]

# %%
# Display image from array
plt.imshow(img_arr, cmap='gray', vmin = 0, vmax = 255)
